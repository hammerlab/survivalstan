# %% [markdown]
# # Worked examples
#
# Each of the following notebooks walks through an analysis of simulated data.
#
# Please submit feedback or comments as an [issue](http://github.com/hammerlab/survivalstan/issues) or on [gitter](https://gitter.im/survivalstan).

# %% [markdown]
# [PEM survival model: unstructured hazard](examples/Example-using-pem_survival_model.ipynb)
#
# [PEM survival model: gamma hazard](examples/Test pem_survival_model_gamma with simulated data.ipynb)
#
# [PEM survival model: randomwalk hazard](examples/Test pem_survival_model_randomwalk with simulated data.ipynb)
#
# [PEM survival model: time-dependent effects](examples/Test pem_survival_model_timevarying with simulated data.ipynb)
#
# [User-supplied PEM survival model with gamma hazard](examples/Test new_gamma_survival_model with simulated data.ipynb)
